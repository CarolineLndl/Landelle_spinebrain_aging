# %% [markdown]
# # Computing ALFF
# Imput data should not be band pass and standardize

# %% [markdown]
# ## <font color=#B2D732> <span style="background-color: #4424D6"> Imports

# %%
import sys, glob
main_dir="/cerebro/cerebro1/dataset/bmpd/derivatives/Aging_project/"

sys.path.append(main_dir + "/2025_brsc_aging_project/code/")
from connectivity.alff import ALFF
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import nibabel as nib
import os.path
import json

from plotting import Plotting

# Set numpy to print only 2 decimal digits for neatness
np.set_printoptions(precision=2, suppress=True)

# bibliography:
# https://doi.org/10.1016/j.neuroimage.2009.09.037

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## <font color=#B2D732> <span style="background-color: #4424D6"> Load configuration

# %%
with open('../../config/analyses/brsc_functional.json') as config_file:
    config = json.load(config_file)

# %% [markdown]
# ## <font color=#B2D732> <span style="background-color: #4424D6"> 1. ALFF computations

# %% [markdown]
# #### A. Create instance of ALFF class for further analyses

# %%
#redo with smoothed data to compare
structure='spinalcord' #'spinalcord'
ana="alff"
alff = ALFF(config,IDs=config["participants_IDs_ALL"],structure=structure,analysis=ana)
# Out:
# Output directory: /cerebro/cerebro1/dataset/bmpd/derivatives/Aging_project//figures/f02_functional_sc/preprint2025/alff/spinalcord//alff/slow5/

# %% [markdown]
# #### B. Compute individual maps

# %%
fwhm=[3,3,3] if structure =="spinalcord" else [1,1,1]
alff_files,zalff_files=alff.compute_alff_maps(fwhm=fwhm,scaling_method="zscore",redo=False,n_jobs=4)
# Out:
# ALFF MAPS COMPUTATION
# Overwrite old files: False
# ... Preparing data
# ... alff is Running
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   1 tasks      | elapsed:    8.7s
# [Parallel(n_jobs=4)]: Done   2 tasks      | elapsed:    8.7s
# [Parallel(n_jobs=4)]: Done   3 tasks      | elapsed:    8.7s
# [Parallel(n_jobs=4)]: Done   4 tasks      | elapsed:    8.7s
# [Parallel(n_jobs=4)]: Done   5 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=4)]: Done   6 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=4)]: Done   7 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=4)]: Done   8 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=4)]: Done   9 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=4)]: Done  10 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=4)]: Done  11 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=4)]: Done  12 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=4)]: Done  13 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=4)]: Done  14 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=4)]: Done  15 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=4)]: Done  16 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=4)]: Done  17 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=4)]: Done  18 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=4)]: Done  19 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=4)]: Done  20 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=4)]: Done  21 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=4)]: Done  22 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=4)]: Done  23 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=4)]: Done  25 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=4)]: Done  26 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=4)]: Batch computation too fast (0.1639753259748164s.) Setting batch_size=2.
# [Parallel(n_jobs=4)]: Done  27 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=4)]: Done  28 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=4)]: Done  29 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=4)]: Done  30 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=4)]: Done  31 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=4)]: Done  32 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=4)]: Done  33 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=4)]: Done  34 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=4)]: Done  35 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=4)]: Done  36 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=4)]: Done  38 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=4)]: Batch computation too fast (0.007050514221191406s.) Setting batch_size=4.
# [Parallel(n_jobs=4)]: Done  40 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=4)]: Done  44 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=4)]: Done  46 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=4)]: Done  48 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=4)]: Done  50 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=4)]: Done  52 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=4)]: Done  53 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=4)]: Done  54 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=4)]: Done  55 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=4)]: Done  56 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=4)]: Done  57 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=4)]: Done  58 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=4)]: Done  59 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=4)]: Done  60 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=4)]: Done  61 out of  67 | elapsed:    8.8s remaining:    0.9s
# [Parallel(n_jobs=4)]: Done  62 out of  67 | elapsed:    8.8s remaining:    0.7s
# [Parallel(n_jobs=4)]: Done  63 out of  67 | elapsed:    8.8s remaining:    0.6s
# [Parallel(n_jobs=4)]: Done  64 out of  67 | elapsed:    8.8s remaining:    0.4s
# [Parallel(n_jobs=4)]: Done  65 out of  67 | elapsed:    8.8s remaining:    0.3s
# [Parallel(n_jobs=4)]: Done  67 out of  67 | elapsed:    8.8s finished
# ... Operation performed in 8.813 s
# ...DONE!

# %% [markdown]
# ## <font color=#B2D732> <span style="background-color: #4424D6"> 2. ALFF ROI analyses

# %% [markdown]
# ### A. Compute values per ROI
# - within gm mask

# %%
alff_df={}

if structure =="brain":
    atlas={"schaefer200_cobra":"schaefer200_cobra"}
    template_dir=config["project_dir"] + "/templates/MNI/atlas/"
    tag_sup="/"
else:
    atlas={"levels":"_"}
    template_dir=config["project_dir"] + "/templates/PAM50/atlas/Frostell"
    tag_sup="28Parcels_7Networks/Frostell"

#---- Load image and label file
for tag_nb, tag in enumerate(atlas):
    atlas_f=glob.glob(template_dir+atlas[tag]+tag_sup+atlas[tag]+"*.nii.gz")[0]
    atlas_labels=glob.glob(template_dir+atlas[tag]+tag_sup+atlas[tag]+"*.txt")[0]
    labelslist=np.genfromtxt(atlas_labels, usecols=1,skip_header=1, dtype="S", delimiter="\t", encoding=None).astype(str)
    labelsnb=np.genfromtxt(atlas_labels, usecols=0,skip_header=1, dtype="S", delimiter="\t", encoding=None).astype(str)
    alff_df[tag]=alff.extract_alff_rois(input_f=alff_files,atlas_f=atlas_f,atlas_labels=labelslist,atlas_labels_nb=labelsnb,tag="_" + tag,redo=True,plot=False,verbose=0)
# Out:
# ALFF IN ROIS
# Overwritting old files
